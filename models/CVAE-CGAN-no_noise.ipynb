# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow as tf
tf.keras.utils.set_random_seed(3)
from tqdm import tqdm
from tensorflow.keras.utils import plot_model
import time

# %% [markdown]
# # Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_path = "/content/drive/MyDrive/Cursos/TFM_AI/TFM/aplicacion/data/train.npz"
test_path = "/content/drive/MyDrive/Cursos/TFM_AI/TFM/aplicacion/data/test.npz"
model_path = "/content/drive/MyDrive/Cursos/TFM_AI/TFM/aplicacion/models/cvae-cgan_no_noise.h5"

"""
train_path = "data/train.npz"
test_path = "data/test.npz"
model_path = "models/cvae-cgan_no_noise.h5"
"""
# Out:
# '\ntrain_path = "data/train.npz"\ntest_path = "data/test.npz"\nmodel_path = "models/cvae-cgan_no_noise.h5"\n'

# %%
train_data = np.load(train_path)
X_train = train_data["arr_0"]
y_train = train_data["arr_1"]
X_train.shape, y_train.shape
# Out:
# ((10000, 128, 128, 1), (10000,))

# %%
test_data = np.load(test_path)
X_test = test_data["arr_0"]
y_test = test_data["arr_1"]
X_test.shape, y_test.shape
# Out:
# ((400, 128, 128, 1), (400,))

# %%
X_train = X_train / 255.
X_test = X_test / 255.

# %% [markdown]
# # Model

# %%
latent_dim = 32
n_classes = 2
images_shape = X_train[0].shape # (128, 128, 1)

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
# Encoder
encoder_input = keras.Input(shape=images_shape)
label_input = keras.Input(shape=())
label = layers.Embedding(n_classes, np.prod(images_shape), input_length=1)(label_input)
label = layers.Reshape(images_shape)(label)

x = keras.layers.Concatenate()([encoder_input, label])

x1 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x1)
x = tf.add(x, x1)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)

x1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x1)
x = tf.add(x, x1)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)

x1 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x1)
x = tf.add(x, x1)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)

x1 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x1)
x = tf.add(x, x1)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)

shape_before_flattening = x.shape[1:]
print(shape_before_flattening)
x = layers.Flatten()(x)

z_mean = layers.Dense(latent_dim, name="z_mean")(x) 
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])

encoder = keras.Model([encoder_input, label_input], [z_mean, z_log_var, z], name="encoder") 
#we need to output also z_mean and z_log_var to calculate the kl loss
encoder.summary()
# Out:
# (8, 8, 256)
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None,)]            0           []
#
#  embedding (Embedding)          (None, 16384)        32768       ['input_2[0][0]']
#
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  reshape (Reshape)              (None, 128, 128, 1)  0           ['embedding[0][0]']
#
#  concatenate (Concatenate)      (None, 128, 128, 2)  0           ['input_1[0][0]',
#                                                                   'reshape[0][0]']
#
#  conv2d (Conv2D)                (None, 128, 128, 32  608         ['concatenate[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 32  9248        ['conv2d[0][0]']
#                                 )
#
#  tf.math.add (TFOpLambda)       (None, 128, 128, 32  0           ['conv2d_1[0][0]',
#                                 )                                 'conv2d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 128, 128, 32  128        ['tf.math.add[0][0]']
#  alization)                     )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 32)   0           ['batch_normalization[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 64)   18496       ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 64)   36928       ['conv2d_2[0][0]']
#
#  tf.math.add_1 (TFOpLambda)     (None, 64, 64, 64)   0           ['conv2d_3[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 64, 64, 64)  256         ['tf.math.add_1[0][0]']
#  rmalization)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 128)  147584      ['conv2d_4[0][0]']
#
#  tf.math.add_2 (TFOpLambda)     (None, 32, 32, 128)  0           ['conv2d_5[0][0]',
#                                                                   'conv2d_4[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 128)  512        ['tf.math.add_2[0][0]']
#  rmalization)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 128)  0          ['batch_normalization_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 256)  590080      ['conv2d_6[0][0]']
#
#  tf.math.add_3 (TFOpLambda)     (None, 16, 16, 256)  0           ['conv2d_7[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 16, 16, 256)  1024       ['tf.math.add_3[0][0]']
#  rmalization)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 256)   0           ['batch_normalization_3[0][0]']
#
#  flatten (Flatten)              (None, 16384)        0           ['max_pooling2d_3[0][0]']
#
#  z_mean (Dense)                 (None, 32)           524320      ['flatten[0][0]']
#
#  z_log_var (Dense)              (None, 32)           524320      ['flatten[0][0]']
#
#  sampling (Sampling)            (None, 32)           0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 2,255,296
# Trainable params: 2,254,336
# Non-trainable params: 960
# __________________________________________________________________________________________________

# %%
plot_model(encoder)

# %%
# Decoder
latent_input = keras.Input(shape=(latent_dim,), name='decoder_input')
label = layers.Embedding(n_classes, latent_dim, input_length=1)(label_input)
x = layers.Concatenate()([latent_input, label])
x = layers.Dense(np.prod(shape_before_flattening))(x)
x = layers.Reshape(shape_before_flattening)(x)

x1 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x1)
x = tf.add(x, x1)
x = layers.BatchNormalization()(x)
x = layers.UpSampling2D((2, 2))(x)

x1 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x1)
x = tf.add(x, x1)
x = layers.BatchNormalization()(x)
x = layers.UpSampling2D((2, 2))(x)

x1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x1)
x = tf.add(x, x1)
x = layers.BatchNormalization()(x)
x = layers.UpSampling2D((2, 2))(x)

x1 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x1)
x = tf.add(x, x1)
x = layers.BatchNormalization()(x)
x = layers.UpSampling2D((2, 2))(x)

decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

decoder = keras.Model([latent_input, label_input], decoded, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None,)]            0           []
#
#  decoder_input (InputLayer)     [(None, 32)]         0           []
#
#  embedding_1 (Embedding)        (None, 32)           64          ['input_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 64)           0           ['decoder_input[0][0]',
#                                                                   'embedding_1[0][0]']
#
#  dense (Dense)                  (None, 16384)        1064960     ['concatenate_1[0][0]']
#
#  reshape_1 (Reshape)            (None, 8, 8, 256)    0           ['dense[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 256)    590080      ['reshape_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 256)    590080      ['conv2d_8[0][0]']
#
#  tf.math.add_4 (TFOpLambda)     (None, 8, 8, 256)    0           ['conv2d_9[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 8, 8, 256)   1024        ['tf.math.add_4[0][0]']
#  rmalization)
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 256)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 128)  295040      ['up_sampling2d[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 128)  147584      ['conv2d_10[0][0]']
#
#  tf.math.add_5 (TFOpLambda)     (None, 16, 16, 128)  0           ['conv2d_11[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 16, 16, 128)  512        ['tf.math.add_5[0][0]']
#  rmalization)
#
#  up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 128)  0          ['batch_normalization_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 64)   73792       ['up_sampling2d_1[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 64)   36928       ['conv2d_12[0][0]']
#
#  tf.math.add_6 (TFOpLambda)     (None, 32, 32, 64)   0           ['conv2d_13[0][0]',
#                                                                   'conv2d_12[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 64)  256         ['tf.math.add_6[0][0]']
#  rmalization)
#
#  up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 64)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 32)   18464       ['up_sampling2d_2[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 32)   9248        ['conv2d_14[0][0]']
#
#  tf.math.add_7 (TFOpLambda)     (None, 64, 64, 32)   0           ['conv2d_15[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 32)  128         ['tf.math.add_7[0][0]']
#  rmalization)
#
#  up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 32  0          ['batch_normalization_7[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 1)  289         ['up_sampling2d_3[0][0]']
#
# ==================================================================================================
# Total params: 2,828,449
# Trainable params: 2,827,489
# Non-trainable params: 960
# __________________________________________________________________________________________________

# %%
plot_model(decoder)

# %%
# VAE
encoder_input = keras.Input(shape=images_shape)
label_input = keras.Input(shape=())
z_mean, z_log_var, z = encoder([encoder_input, label_input])
decoded = decoder([z, label_input])
vae = keras.Model([encoder_input, label_input], decoded, name="vae")
vae.summary()
# Out:
# Model: "vae"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  input_4 (InputLayer)           [(None,)]            0           []
#
#  encoder (Functional)           [(None, 32),         2255296     ['input_3[0][0]',
#                                  (None, 32),                      'input_4[0][0]']
#                                  (None, 32)]
#
#  decoder (Functional)           (None, 128, 128, 1)  2828449     ['encoder[0][2]',
#                                                                   'input_4[0][0]']
#
# ==================================================================================================
# Total params: 5,083,745
# Trainable params: 5,081,825
# Non-trainable params: 1,920
# __________________________________________________________________________________________________

# %%
# Discriminador
discriminator_inputs = keras.Input(shape=images_shape)
label_input = keras.Input(shape=())
cond = layers.Embedding(n_classes, np.prod(images_shape), input_length=1)(label_input) #10 clases 
cond = layers.Reshape(images_shape)(cond)
x = keras.layers.Concatenate()([discriminator_inputs, cond])


x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)

x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)

x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)

x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)

x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.GlobalMaxPool2D()(x)

x = layers.Dropout(0.2)(x)
x = layers.Dense(128, activation="relu")(x)
x = layers.Dropout(0.2)(x)
x = layers.Dense(32, activation="relu")(x)

discriminator_output = layers.Dense(1, activation="sigmoid")(x)

discriminator = keras.Model([discriminator_inputs, label_input], discriminator_output)
discriminator.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
discriminator.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None,)]            0           []
#
#  embedding_2 (Embedding)        (None, 16384)        32768       ['input_6[0][0]']
#
#  input_5 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  reshape_2 (Reshape)            (None, 128, 128, 1)  0           ['embedding_2[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 2)  0           ['input_5[0][0]',
#                                                                   'reshape_2[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 32  608         ['concatenate_2[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 128, 128, 32  128        ['conv2d_17[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 64, 64, 32)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 64, 64, 32)   9248        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_18[0][0]']
#  rmalization)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 32, 32, 32)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 64)   18496       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 64)  256         ['conv2d_19[0][0]']
#  ormalization)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 16, 16, 64)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 16, 16, 64)   36928       ['max_pooling2d_6[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 16, 16, 64)  256         ['conv2d_20[0][0]']
#  ormalization)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 8, 8, 64)    0           ['batch_normalization_11[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 8, 8, 128)    73856       ['max_pooling2d_7[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 8, 8, 128)   512         ['conv2d_21[0][0]']
#  ormalization)
#
#  global_max_pooling2d (GlobalMa  (None, 128)         0           ['batch_normalization_12[0][0]']
#  xPooling2D)
#
#  dropout (Dropout)              (None, 128)          0           ['global_max_pooling2d[0][0]']
#
#  dense_1 (Dense)                (None, 128)          16512       ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 128)          0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 32)           4128        ['dropout_1[0][0]']
#
#  dense_3 (Dense)                (None, 1)            33          ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 193,857
# Trainable params: 193,217
# Non-trainable params: 640
# __________________________________________________________________________________________________

# %%
from keras import backend as K
class VAE_GAN(keras.Model):    

    def __init__(self, vae, discriminator, **kwargs): #opti1=keras.optimizers.Adam(), opti2=keras.optimizers.Adam(), opti3=keras.optimizers.Adam(),
        super().__init__(**kwargs)
        
        self.encoder = vae.get_layer("encoder")#vae.encoder
        self.decoder = vae.get_layer("decoder")#vae.decoder
        self.discriminator = discriminator
        self.vae = vae
        
        self.vae_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")
        #self.correlation_loss_tracker = keras.metrics.Mean(name="cr_loss")
        self.disc_loss_tracker = keras.metrics.Mean(name="disc_loss")
        self.gen_loss_tracker = keras.metrics.Mean(name="gen_loss")
        self.disc_loss = keras.losses.BinaryCrossentropy()
        self.disc_accuracy = keras.metrics.BinaryAccuracy()
        
        
    def call(self,inputs):
        x, y = inputs
        z_mean, z_log_var, z = self.encoder([x, y])
        reconstruction = self.decoder([z, y])
        return reconstruction, z

    @property
    def metrics(self):
        return [
            self.vae_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
            #self.correlation_loss_tracker,
            self.disc_loss_tracker,
            self.gen_loss_tracker
        ]
    
    def compile(self, **kwargs): #gen_optimizer=keras.optimizers.Adam(), 
        super().compile(**kwargs)
        lr = self.optimizer.lr
        self.vae_optimizer = keras.optimizers.Adam(lr) #this is a trick to get the lr of the default optimizer
        #as it is passing the reference the lr of our optimizers will also update with ReduceLROnPlateau
        self.disc_optimizer = keras.optimizers.Adam(lr)
        #self.gen_optimizer=keras.optimizers.Adam(lr) 

    def train_step(self, inputs): 
        data, label = inputs
        batch_size = K.shape(data)[0]    
        
        with tf.GradientTape() as enc_tape, tf.GradientTape() as disc_tape: # tf.GradientTape() as dec_tape
            z_mean, z_log_var, z = self.encoder([data, label])
            reconstruction = self.decoder([z, label])
            reconstruction_loss = tf.reduce_mean(
            tf.reduce_sum(keras.losses.mse(data, reconstruction), axis=(1, 2)))
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            #coorelation_loss = corr_loss(z)
            
            
            # GAN
            recon_vect = z
            combined_images = tf.concat([data, reconstruction], axis=0) #256
            data_l,recon_l = tf.zeros((batch_size, 1)),tf.ones((batch_size, 1))
            
            combined_l = tf.concat([data_l, recon_l], axis=0) #256
            double_label = tf.repeat(label, 2, axis=0)
            
            tot_predictions = self.discriminator([combined_images, double_label])
            r_prediction = self.discriminator([reconstruction, label])
            discr_loss = self.disc_loss(combined_l, tot_predictions)


            #fake labels : 
            #gen_loss =  self.disc_loss(recon_l,r_prediction)
            #gen_loss =  tf.math.maximum(self.disc_loss(data_l,r_prediction), 0.0001)
            gen_loss = tf.math.maximum(self.disc_loss(data_l,r_prediction) - discr_loss,.0001)
    

            vae_loss = reconstruction_loss + kl_loss + gen_loss #+.1*coorelation_loss 

               
        grad_discr = disc_tape.gradient(discr_loss, self.discriminator.trainable_weights)
        grad_vae = enc_tape.gradient(vae_loss, self.vae.trainable_weights)
        #grad_gen = dec_tape.gradient(gen_loss, self.decoder.trainable_weights)
        
        
        #self.gen_optimizer.apply_gradients(zip(grad_gen, self.decoder.trainable_weights))
        self.disc_optimizer.apply_gradients(zip(grad_discr, self.discriminator.trainable_weights))
        self.vae_optimizer.apply_gradients(zip(grad_vae, self.vae.trainable_weights))

                                           
        self.vae_loss_tracker.update_state(vae_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        #self.correlation_loss_tracker.update_state(coorelation_loss)
        self.disc_loss_tracker.update_state(discr_loss)
        self.gen_loss_tracker.update_state(gen_loss)
        self.disc_accuracy.update_state(combined_l, tot_predictions)
        
        return {
            "vae_loss": self.vae_loss_tracker.result(),
            "r_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
            "disc_loss": self.disc_loss_tracker.result(),
            "gen_loss": self.gen_loss_tracker.result(),
            "disc_acc": self.disc_accuracy.result()
        }
    
    def test_step(self, inputs): 
        data, label = inputs
        batch_size = K.shape(data)[0]    
        

        z_mean, z_log_var, z = self.encoder([data, label])
        reconstruction = self.decoder([z, label])
        reconstruction_loss = tf.reduce_mean(
        tf.reduce_sum(keras.losses.mse(data, reconstruction), axis=(1, 2)))
        kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
        kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
        #coorelation_loss = corr_loss(z)


        # GAN
        recon_vect = z
        combined_images = tf.concat([data, reconstruction], axis=0) #256
        data_l,recon_l = tf.zeros((batch_size, 1)),tf.ones((batch_size, 1))

        combined_l = tf.concat([data_l, recon_l], axis=0) #256
        double_label = tf.repeat(label, 2, axis=0)

        tot_predictions = self.discriminator([combined_images, double_label])
        r_prediction = self.discriminator([reconstruction, label])
        discr_loss = self.disc_loss(combined_l, tot_predictions)


        #fake labels : 
        #gen_loss =  self.disc_loss(recon_l,r_prediction)
        #gen_loss =  tf.math.maximum(self.disc_loss(data_l,r_prediction), 0.0001)
        gen_loss = tf.math.maximum(self.disc_loss(data_l,r_prediction) - discr_loss,.0001)

        vae_loss = reconstruction_loss + kl_loss + gen_loss #+.1*coorelation_loss 

                                           
        self.vae_loss_tracker.update_state(vae_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        #self.correlation_loss_tracker.update_state(coorelation_loss)
        self.disc_loss_tracker.update_state(discr_loss)
        self.gen_loss_tracker.update_state(gen_loss)
        self.disc_accuracy.update_state(combined_l, tot_predictions)
        
        return {
            "vae_loss": self.vae_loss_tracker.result(),
            "r_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
            "disc_loss": self.disc_loss_tracker.result(),
            "gen_loss": self.gen_loss_tracker.result(),
            "disc_acc": self.disc_accuracy.result()
        }

# %%
model = VAE_GAN(vae, discriminator)
model.compile(optimizer = keras.optimizers.Adam(0.001))

# %%
early_stop = keras.callbacks.EarlyStopping(monitor="val_vae_loss", min_delta=0.1, patience=10, restore_best_weights=True)
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_vae_loss', factor=0.2, patience=5, min_lr=1e-5)

# %%
init_time = time.time()
logs = model.fit(X_train, y_train, epochs=100, batch_size=32, 
               validation_data=(X_test, y_test), 
               callbacks=[early_stop, reduce_lr]) 
print(f"Total time: {time.time() - init_time} (s)")
# Out:
# Epoch 1/100
# Epoch 32/100
# 313/313 [==============================] - 40s 126ms/step - vae_loss: 144.6201 - r_loss: 102.0427 - kl_loss: 36.3685 - disc_loss: 0.0510 - gen_loss: 6.2793 - disc_acc: 0.9833 - val_vae_loss: 139.3579 - val_r_loss: 96.4254 - val_kl_loss: 37.1220 - val_disc_loss: 0.1580 - val_gen_loss: 5.8105 - val_disc_acc: 0.9832 - lr: 4.0000e-05
# Epoch 33/100
# 313/313 [==============================] - 40s 126ms/step - vae_loss: 143.9170 - r_loss: 101.3231 - kl_loss: 36.4876 - disc_loss: 0.0520 - gen_loss: 6.1815 - disc_acc: 0.9831 - val_vae_loss: 139.2925 - val_r_loss: 95.9236 - val_kl_loss: 37.5758 - val_disc_loss: 0.1443 - val_gen_loss: 5.7931 - val_disc_acc: 0.9831 - lr: 4.0000e-05
# Epoch 34/100
# 313/313 [==============================] - 40s 126ms/step - vae_loss: 144.2561 - r_loss: 101.1449 - kl_loss: 36.4872 - disc_loss: 0.0398 - gen_loss: 6.4314 - disc_acc: 0.9831 - val_vae_loss: 139.4922 - val_r_loss: 96.4790 - val_kl_loss: 37.1484 - val_disc_loss: 0.1432 - val_gen_loss: 5.8648 - val_disc_acc: 0.9831 - lr: 4.0000e-05
# Epoch 35/100
# 313/313 [==============================] - 40s 126ms/step - vae_loss: 144.5659 - r_loss: 101.3724 - kl_loss: 36.5624 - disc_loss: 0.0406 - gen_loss: 6.4612 - disc_acc: 0.9831 - val_vae_loss: 140.2782 - val_r_loss: 96.4697 - val_kl_loss: 37.4454 - val_disc_loss: 0.1585 - val_gen_loss: 6.3631 - val_disc_acc: 0.9831 - lr: 4.0000e-05
# Epoch 36/100
# 313/313 [==============================] - 40s 127ms/step - vae_loss: 143.9996 - r_loss: 100.8360 - kl_loss: 36.5112 - disc_loss: 0.0418 - gen_loss: 6.5342 - disc_acc: 0.9832 - val_vae_loss: 139.2233 - val_r_loss: 96.3366 - val_kl_loss: 37.0298 - val_disc_loss: 0.1393 - val_gen_loss: 5.8570 - val_disc_acc: 0.9831 - lr: 4.0000e-05
# Total time: 1429.2520661354065 (s)

# %%
vae.save(model_path)
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
plt.plot(logs.history['vae_loss'], label="loss")
plt.plot(logs.history['val_vae_loss'], label="val_loss")
plt.legend()
plt.show()

# %%
plt.plot(logs.history['r_loss'], label="r_loss")
plt.plot(logs.history['val_r_loss'], label="val_r_loss")
plt.legend()
plt.show()

# %%
plt.plot(logs.history['kl_loss'], label="r_loss")
plt.plot(logs.history['val_kl_loss'], label="val_r_loss")
plt.legend()
plt.show()

# %%
plt.plot(logs.history['disc_loss'], label="r_loss")
plt.plot(logs.history['val_disc_loss'], label="val_r_loss")
plt.legend()
plt.show()

# %%
plt.plot(logs.history['disc_acc'], label="r_loss")
plt.plot(logs.history['val_disc_acc'], label="val_r_loss")
plt.legend()
plt.show()

# %% [markdown]
# # Testing

# %%
# optional
vae = keras.models.load_model(model_path, custom_objects={'Sampling': Sampling}, compile=False)
vae.summary()
# Out:
# Model: "vae"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  input_4 (InputLayer)           [(None,)]            0           []
#
#  encoder (Functional)           [(None, 32),         2255296     ['input_3[0][0]',
#                                  (None, 32),                      'input_4[0][0]']
#                                  (None, 32)]
#
#  decoder (Functional)           (None, 128, 128, 1)  2828449     ['encoder[0][2]',
#                                                                   'input_4[0][0]']
#
# ==================================================================================================
# Total params: 5,083,745
# Trainable params: 5,081,825
# Non-trainable params: 1,920
# __________________________________________________________________________________________________

# %%
decoded_imgs = vae.predict([X_test, y_test])

n = 5
plt.figure(figsize=(20, 10))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(X_test[i].reshape(128, 128))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(128, 128))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# 13/13 [==============================] - 0s 19ms/step

# %% [markdown]
# # Sampling a image from noise

# %%
decoder = vae.get_layer("decoder")
encoder = vae.get_layer("encoder")

# %%
batch = 4
classes = np.array([0,0,1,1])
cond_inp_str = np.where(classes==0, "negative", "positive")

ruido = np.random.randn(batch, latent_dim)
gen_imgs = decoder.predict([ruido, classes])
gen_imgs.shape
# Out:
# 1/1 [==============================] - 0s 103ms/step
# (4, 128, 128, 1)

# %%
plt.figure(figsize=(15, 8))
for i in range(1,batch+1):
    ax = plt.subplot(1, batch, i)
    ax.imshow(np.squeeze(gen_imgs[i-1]), cmap="gray")
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    ax.set_title(f"Generated {cond_inp_str[i-1]}")
plt.show()

# %% [markdown]
# ## Modifying the Z to generate new images.

# %%
idx = 1
img = X_test[idx].squeeze()

# %%
plt.imshow(img, cmap="gray")
plt.axis("off")
plt.title("Original")
plt.show()

# %%
label = y_test[idx][None, ...]
img_input = img[None, ..., None]
label
# Out:
# array([0], dtype=uint8)

# %%
_,_, encoded = encoder.predict([img_input, label])
decoded = decoder.predict([encoded, label])
decoded.shape
# Out:
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 43ms/step
# (1, 128, 128, 1)

# %%
plt.imshow(decoded.squeeze(), cmap="gray")
plt.axis("off")
plt.title("Reconstructed")
plt.show()

# %%
encoded.shape
# Out:
# (1, 32)

# %%
n = latent_dim//8

# %%
fig, axis = plt.subplots(6,n, figsize=(16,20)) #ancho,alto
for j in range(n):
    for index, i in enumerate(np.linspace(-4, 4, 6)):
        lista_temp = [0]*latent_dim
        lista_temp[j] = i
        modified = encoded + np.array([lista_temp])
        decoded = decoder.predict([modified, label], verbose=0)
        axis[index, j].imshow(decoded.squeeze(), cmap="gray")
        axis[index, j].axis('off')
        axis[index, j].set_aspect('equal')
plt.subplots_adjust(wspace=0, hspace=0)
plt.show()

# %% [markdown]
# ## Changing Label

# %%
label_sw = np.where(label == 0, 1, 0) #switching the label
label_sw
# Out:
# array([1])

# %%
_,_, encoded = encoder.predict([img_input, label_sw])
decoded = decoder.predict([encoded, label_sw])
decoded.shape
# Out:
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 49ms/step
# (1, 128, 128, 1)

# %%
plt.imshow(decoded.squeeze(), cmap="gray")
plt.axis("off")
plt.title("Reconstructed Label Switched")
plt.show()
